# %% [markdown]
# This is the
# [MNIST example](https://keras.io/examples/vision/mnist_convnet/)
# from the Keras documentation, for testing its neural network separately from the main project.

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                16010
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                16010
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 17s 22ms/step - loss: 0.7896 - accuracy: 0.7572 - val_loss: 0.0894 - val_accuracy: 0.9745
# Epoch 2/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.1204 - accuracy: 0.9627 - val_loss: 0.0623 - val_accuracy: 0.9825
# Epoch 3/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0860 - accuracy: 0.9733 - val_loss: 0.0491 - val_accuracy: 0.9865
# Epoch 4/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0741 - accuracy: 0.9784 - val_loss: 0.0398 - val_accuracy: 0.9888
# Epoch 5/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0631 - accuracy: 0.9802 - val_loss: 0.0391 - val_accuracy: 0.9885
# Epoch 6/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0567 - accuracy: 0.9817 - val_loss: 0.0338 - val_accuracy: 0.9912
# Epoch 7/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0511 - accuracy: 0.9839 - val_loss: 0.0373 - val_accuracy: 0.9898
# Epoch 8/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0465 - accuracy: 0.9851 - val_loss: 0.0368 - val_accuracy: 0.9895
# Epoch 9/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0473 - accuracy: 0.9838 - val_loss: 0.0299 - val_accuracy: 0.9923
# Epoch 10/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0395 - accuracy: 0.9877 - val_loss: 0.0309 - val_accuracy: 0.9908
# Epoch 11/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0373 - accuracy: 0.9881 - val_loss: 0.0306 - val_accuracy: 0.9908
# Epoch 12/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0360 - accuracy: 0.9886 - val_loss: 0.0299 - val_accuracy: 0.9913
# Epoch 13/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0344 - accuracy: 0.9894 - val_loss: 0.0293 - val_accuracy: 0.9917
# Epoch 14/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.0274 - val_accuracy: 0.9925
# Epoch 15/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0347 - accuracy: 0.9882 - val_loss: 0.0272 - val_accuracy: 0.9917
# Epoch 1/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.7552 - accuracy: 0.7655 - val_loss: 0.0800 - val_accuracy: 0.9790
# Epoch 2/15
# 422/422 [==============================] - 3s 6ms/step - loss: 0.1204 - accuracy: 0.9645 - val_loss: 0.0587 - val_accuracy: 0.9838
# Epoch 3/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0891 - accuracy: 0.9718 - val_loss: 0.0492 - val_accuracy: 0.9868
# Epoch 4/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0691 - accuracy: 0.9779 - val_loss: 0.0428 - val_accuracy: 0.9885
# Epoch 5/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0615 - accuracy: 0.9813 - val_loss: 0.0376 - val_accuracy: 0.9898
# Epoch 6/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0557 - accuracy: 0.9823 - val_loss: 0.0362 - val_accuracy: 0.9912
# Epoch 7/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0473 - accuracy: 0.9848 - val_loss: 0.0352 - val_accuracy: 0.9905
# Epoch 8/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0445 - accuracy: 0.9856 - val_loss: 0.0372 - val_accuracy: 0.9887
# Epoch 9/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0437 - accuracy: 0.9854 - val_loss: 0.0346 - val_accuracy: 0.9917
# Epoch 10/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0417 - accuracy: 0.9863 - val_loss: 0.0300 - val_accuracy: 0.9920
# Epoch 11/15
# 422/422 [==============================] - 3s 6ms/step - loss: 0.0413 - accuracy: 0.9875 - val_loss: 0.0300 - val_accuracy: 0.9917
# Epoch 12/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0387 - accuracy: 0.9877 - val_loss: 0.0277 - val_accuracy: 0.9928
# Epoch 13/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0346 - accuracy: 0.9885 - val_loss: 0.0280 - val_accuracy: 0.9930
# Epoch 14/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 0.0338 - val_accuracy: 0.9915
# Epoch 15/15
# 422/422 [==============================] - 3s 7ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.0303 - val_accuracy: 0.9920

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.02372121810913086
# Test accuracy: 0.9916999936103821
# Test loss: 0.02757992595434189
# Test accuracy: 0.9915000200271606
